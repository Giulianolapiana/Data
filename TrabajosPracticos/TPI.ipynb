# %%
import kagglehub 
# Download latest version 
path = kagglehub.dataset_download("nitikachandel95/student-social-media-impact-dataset") 
print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\giuli\.cache\kagglehub\datasets\nitikachandel95\student-social-media-impact-dataset\versions\7

# %%
import pandas as pd
import os

print(os.listdir(path))

df = pd.read_csv(f"{path}/global_student_digital_behavior_dataset.csv")

print(df.shape)
# Out:
# ['global_student_digital_behavior_dataset.csv']
# (500000, 48)
